# %%
import pandas as pd
import numpy as np
from pprint import pprint

# %%
#import the dataset
training_data = pd.read_csv("project1 1.data",header=None, names=['price','maint','doors','persons','lug_boot','safety','result'])
testing_data = pd.read_csv("project1_test.data",header=None, names=['price','maint','doors','persons','lug_boot','safety','result'])

# %%
###defining entropy
def entropy(target_col):
    #using unique ,getting the number  unique elements and elements
    elements,counts = np.unique(target_col,return_counts=True)
    #formula
    entropy = np.sum([(-counts[i]/np.sum(counts))*np.log2(counts[i]/np.sum(counts)) for i in range(len(elements))])
    return entropy
  
##Info Gain

def InfoGain(data,split_attribute_name,target_name="result"):
    #calculate total entropy
    total_entropy = entropy(data[target_name])
    #get individual values
    vals,counts = np.unique(data[split_attribute_name],return_counts=True)
    #cal the weighted entropy
    Weighted_Entropy = np.sum([(counts[i]/np.sum(counts))*entropy(data.where(data[split_attribute_name]==vals[i]).
                                dropna()[target_name])for i in range(len(vals))])
    
    #formula for information gain
    Information_Gain = total_entropy-Weighted_Entropy
    return Information_Gain

# %%
def ID3(data,originaldata,features,target_attribute_name="result",
        parent_node_class=None):
    #If all target_values have the same value,return this value
    if len(np.unique(data[target_attribute_name])) <= 1:
        return np.unique(data[target_attribute_name])[0]
    
    #if the dataset is empty
    elif len(data) == 0:
        return np.unique(originaldata[target_attribute_name])[np.argmax(np.unique(originaldata[target_attribute_name],
                                                                           return_counts=True)[1])]
    
    #If the feature space is empty
    elif len(features) == 0:
        return parent_node_class 

    #If none of the above condition holds true grow the tree

    else:
        parent_node_class = np.unique(data[target_attribute_name])[np.argmax(np.unique(data[target_attribute_name],
                                                                           return_counts=True)[1])]

    #Select the feature which best splits the dataset
    item_values = [InfoGain(data,feature,target_attribute_name)for feature in features] #Return the infgain values
    best_feature_index = np.argmax(item_values)
    best_feature = features[best_feature_index]

    #Create the tree structure
    tree = {best_feature:{}}

    #Remve the feature with the best info gain
    features = [i for i in features if i!= best_feature]

    #Grow the tree branch under the root node

    for value in np.unique(data[best_feature]):
        value = value
        sub_data = data.where(data[best_feature]==value).dropna()
        #call the ID3 algotirthm
        subtree = ID3(sub_data,dataset,features,target_attribute_name,parent_node_class)
        #Add the subtree
        tree[best_feature][value] = subtree
    return(tree)

# %%
#Predict
def predict(query,tree,default=1):
    for key in list(query.keys()):
        if key in list(tree.keys()):
            try:
               result = tree[key][query[key]]
            except:
               return default

            result = tree[key][query[key]]
            if isinstance(result,dict):
                return predict(query,result)
            else:
                return result

# %%
##check the accuracy
def test(data,tree):
   queries = data.iloc[:,:-1].to_dict(orient="records")
   predicted = pd.DataFrame(columns=["predicted"])

# %%
#Train the tree,print the tree abnd predict the accuracy
tree = ID3(training_data,training_data,training_data.columns[:-1])
pprint(tree)
# Out:
# {'safety': {'high': {'persons': {2.0: 'unacc',
#                                  4.0: {'price': {'high': {'maint': {'high': 'acc',
#                                                                     'low': 'acc',
#                                                                     'med': 'acc',
#                                                                     'vhigh': 'unacc'}},
#                                                  'low': {'maint': {'high': {'lug_boot': {'big': 'vgood',
#                                                                                          'med': {'doors': {2.0: 'acc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'vgood',
#                                                                                                            6.0: 'vgood'}},
#                                                                                          'small': 'acc'}},
#                                                                    'low': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'good',
#                                                                                                           3.0: 'good',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': 'good'}},
#                                                                    'med': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'good',
#                                                                                                           3.0: 'good',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': 'good'}},
#                                                                    'vhigh': 'acc'}},
#                                                  'med': {'maint': {'high': 'acc',
#                                                                    'low': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'good',
#                                                                                                           3.0: 'good',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': 'good'}},
#                                                                    'med': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'acc',
#                                                                                                           3.0: 'acc',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': 'acc'}},
#                                                                    'vhigh': 'acc'}},
#                                                  'vhigh': {'maint': {'high': 'unacc',
#                                                                      'low': 'acc',
#                                                                      'med': 'acc',
#                                                                      'vhigh': 'unacc'}}}},
#                                  6.0: {'price': {'high': {'maint': {'high': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                           'med': 'acc',
#                                                                                                           'small': 'unacc'}},
#                                                                                        3.0: 'acc',
#                                                                                        4.0: 'acc',
#                                                                                        6.0: 'acc'}},
#                                                                     'low': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                          'med': 'acc',
#                                                                                                          'small': 'unacc'}},
#                                                                                       3.0: 'acc',
#                                                                                       4.0: 'acc',
#                                                                                       6.0: 'acc'}},
#                                                                     'med': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                          'med': 'acc',
#                                                                                                          'small': 'unacc'}},
#                                                                                       3.0: 'acc',
#                                                                                       4.0: 'acc',
#                                                                                       6.0: 'acc'}},
#                                                                     'vhigh': 'unacc'}},
#                                                  'low': {'maint': {'high': {'lug_boot': {'big': 'vgood',
#                                                                                          'med': {'doors': {2.0: 'acc',
#                                                                                                            3.0: 'vgood',
#                                                                                                            4.0: 'vgood',
#                                                                                                            6.0: 'vgood'}},
#                                                                                          'small': {'doors': {2.0: 'unacc',
#                                                                                                              3.0: 'acc',
#                                                                                                              4.0: 'acc',
#                                                                                                              6.0: 'acc'}}}},
#                                                                    'low': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'good',
#                                                                                                           3.0: 'vgood',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': {'doors': {2.0: 'unacc',
#                                                                                                             3.0: 'good',
#                                                                                                             4.0: 'good',
#                                                                                                             6.0: 'good'}}}},
#                                                                    'med': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'good',
#                                                                                                           3.0: 'vgood',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': {'doors': {2.0: 'unacc',
#                                                                                                             3.0: 'good',
#                                                                                                             4.0: 'good',
#                                                                                                             6.0: 'good'}}}},
#                                                                    'vhigh': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                           'med': 'acc',
#                                                                                                           'small': 'unacc'}},
#                                                                                        3.0: 'acc',
#                                                                                        4.0: 'acc',
#                                                                                        6.0: 'acc'}}}},
#                                                  'med': {'maint': {'high': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                          'med': 'acc',
#                                                                                                          'small': 'unacc'}},
#                                                                                       3.0: 'acc',
#                                                                                       4.0: 'acc',
#                                                                                       6.0: 'acc'}},
#                                                                    'low': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'good',
#                                                                                                           3.0: 'vgood',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': {'doors': {2.0: 'unacc',
#                                                                                                             3.0: 'good',
#                                                                                                             4.0: 'good',
#                                                                                                             6.0: 'good'}}}},
#                                                                    'med': {'lug_boot': {'big': 'vgood',
#                                                                                         'med': {'doors': {2.0: 'acc',
#                                                                                                           3.0: 'vgood',
#                                                                                                           4.0: 'vgood',
#                                                                                                           6.0: 'vgood'}},
#                                                                                         'small': {'doors': {2.0: 'unacc',
#                                                                                                             3.0: 'acc',
#                                                                                                             4.0: 'acc',
#                                                                                                             6.0: 'acc'}}}},
#                                                                    'vhigh': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                           'med': 'acc',
#                                                                                                           'small': 'unacc'}},
#                                                                                        3.0: 'acc',
#                                                                                        4.0: 'acc',
#                                                                                        6.0: 'acc'}}}},
#                                                  'vhigh': {'maint': {'high': 'unacc',
#                                                                      'low': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                           'med': 'acc',
#                                                                                                           'small': 'unacc'}},
#                                                                                        3.0: 'acc',
#                                                                                        4.0: 'acc',
#                                                                                        6.0: 'acc'}},
#                                                                      'med': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                           'med': 'acc',
#                                                                                                           'small': 'unacc'}},
#                                                                                        3.0: 'acc',
#                                                                                        4.0: 'acc',
#                                                                                        6.0: 'acc'}},
#                                                                      'vhigh': 'unacc'}}}}}},
#             'low': 'unacc',
#             'med': {'persons': {2.0: 'unacc',
#                                 4.0: {'price': {'high': {'lug_boot': {'big': {'maint': {'high': 'acc',
#                                                                                         'low': 'acc',
#                                                                                         'med': 'acc',
#                                                                                         'vhigh': 'unacc'}},
#                                                                       'med': {'doors': {2.0: 'unacc',
#                                                                                         3.0: 'unacc',
#                                                                                         4.0: {'maint': {'high': 'acc',
#                                                                                                         'low': 'acc',
#                                                                                                         'med': 'acc',
#                                                                                                         'vhigh': 'unacc'}},
#                                                                                         6.0: {'maint': {'high': 'acc',
#                                                                                                         'low': 'acc',
#                                                                                                         'med': 'acc',
#                                                                                                         'vhigh': 'unacc'}}}},
#                                                                       'small': 'unacc'}},
#                                                 'low': {'maint': {'high': 'acc',
#                                                                   'low': {'lug_boot': {'big': 'good',
#                                                                                        'med': {'doors': {2.0: 'acc',
#                                                                                                          3.0: 'acc',
#                                                                                                          4.0: 'good',
#                                                                                                          6.0: 'good'}},
#                                                                                        'small': 'acc'}},
#                                                                   'med': {'lug_boot': {'big': 'good',
#                                                                                        'med': {'doors': {2.0: 'acc',
#                                                                                                          3.0: 'acc',
#                                                                                                          4.0: 'good',
#                                                                                                          6.0: 'good'}},
#                                                                                        'small': 'acc'}},
#                                                                   'vhigh': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'unacc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}}}},
#                                                 'med': {'maint': {'high': {'lug_boot': {'big': 'acc',
#                                                                                         'med': {'doors': {2.0: 'unacc',
#                                                                                                           3.0: 'unacc',
#                                                                                                           4.0: 'acc',
#                                                                                                           6.0: 'acc'}},
#                                                                                         'small': 'unacc'}},
#                                                                   'low': {'lug_boot': {'big': 'good',
#                                                                                        'med': {'doors': {2.0: 'acc',
#                                                                                                          3.0: 'acc',
#                                                                                                          4.0: 'good',
#                                                                                                          6.0: 'good'}},
#                                                                                        'small': 'acc'}},
#                                                                   'med': 'acc',
#                                                                   'vhigh': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'unacc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}}}},
#                                                 'vhigh': {'maint': {'high': 'unacc',
#                                                                     'low': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'unacc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}},
#                                                                     'med': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'unacc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}},
#                                                                     'vhigh': 'unacc'}}}},
#                                 6.0: {'price': {'high': {'lug_boot': {'big': {'maint': {'high': 'acc',
#                                                                                         'low': 'acc',
#                                                                                         'med': 'acc',
#                                                                                         'vhigh': 'unacc'}},
#                                                                       'med': {'maint': {'high': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                         'low': {'doors': {2.0: 'unacc',
#                                                                                                           3.0: 'acc',
#                                                                                                           4.0: 'acc',
#                                                                                                           6.0: 'acc'}},
#                                                                                         'med': {'doors': {2.0: 'unacc',
#                                                                                                           3.0: 'acc',
#                                                                                                           4.0: 'acc',
#                                                                                                           6.0: 'acc'}},
#                                                                                         'vhigh': 'unacc'}},
#                                                                       'small': 'unacc'}},
#                                                 'low': {'maint': {'high': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                         'med': 'acc',
#                                                                                                         'small': 'unacc'}},
#                                                                                      3.0: 'acc',
#                                                                                      4.0: 'acc',
#                                                                                      6.0: 'acc'}},
#                                                                   'low': {'lug_boot': {'big': 'good',
#                                                                                        'med': {'doors': {2.0: 'acc',
#                                                                                                          3.0: 'good',
#                                                                                                          4.0: 'good',
#                                                                                                          6.0: 'good'}},
#                                                                                        'small': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}}}},
#                                                                   'med': {'lug_boot': {'big': 'good',
#                                                                                        'med': {'doors': {2.0: 'acc',
#                                                                                                          3.0: 'good',
#                                                                                                          4.0: 'good',
#                                                                                                          6.0: 'good'}},
#                                                                                        'small': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}}}},
#                                                                   'vhigh': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}}}},
#                                                 'med': {'maint': {'high': {'lug_boot': {'big': 'acc',
#                                                                                         'med': {'doors': {2.0: 'unacc',
#                                                                                                           3.0: 'acc',
#                                                                                                           4.0: 'acc',
#                                                                                                           6.0: 'acc'}},
#                                                                                         'small': 'unacc'}},
#                                                                   'low': {'lug_boot': {'big': 'good',
#                                                                                        'med': {'doors': {2.0: 'acc',
#                                                                                                          3.0: 'good',
#                                                                                                          4.0: 'good',
#                                                                                                          6.0: 'good'}},
#                                                                                        'small': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}}}},
#                                                                   'med': {'doors': {2.0: {'lug_boot': {'big': 'acc',
#                                                                                                        'med': 'acc',
#                                                                                                        'small': 'unacc'}},
#                                                                                     3.0: 'acc',
#                                                                                     4.0: 'acc',
#                                                                                     6.0: 'acc'}},
#                                                                   'vhigh': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}}}},
#                                                 'vhigh': {'maint': {'high': 'unacc',
#                                                                     'low': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}},
#                                                                     'med': {'lug_boot': {'big': 'acc',
#                                                                                          'med': {'doors': {2.0: 'unacc',
#                                                                                                            3.0: 'acc',
#                                                                                                            4.0: 'acc',
#                                                                                                            6.0: 'acc'}},
#                                                                                          'small': 'unacc'}},
#                                                                     'vhigh': 'unacc'}}}}}}}}

# %%
test(testing_data,tree)
testing_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <module>
#       1 test(testing_data,tree)
#       2 testing_data
# ----> 3 predicted
#
# NameError: name 'predicted' is not defined
